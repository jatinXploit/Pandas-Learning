# %%
import numpy as np
import pandas as pd

# %%
labels = [ 'a', 'b', 'c']
my_lists = [10, 20, 30]
arr = np.array([10,20,30])
d = {1:10, 2:20, 3:30}

# %%
pd.Series(my_lists)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(my_lists, index = labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64
