# %%
import numpy as np
import pandas as pd

# %%
data = {
    'name': ['jatin', 'bharteee', 'supriya', 'mayank'],
    'age': [21, 18, 20, 21],
    'city': ['germany', 'spain', 'india', 'USA'],
}
df = pd.DataFrame(data)

# %%
df
# Out:
#        name  age     city
# 0     jatin   21  germany
# 1  bharteee   18    spain
# 2   supriya   20    india
# 3    mayank   21      USA

# %%
df[['name', 'age']]
# Out:
#        name  age
# 0     jatin   21
# 1  bharteee   18
# 2   supriya   20
# 3    mayank   21

# %%
df['designation'] = ['engineer', 'lawyer', 'lawyer', 'engineer']

# %%
df
# Out:
#        name  age     city designation
# 0     jatin   21  germany    engineer
# 1  bharteee   18    spain      lawyer
# 2   supriya   20    india      lawyer
# 3    mayank   21      USA    engineer

# %%
df.drop('designation',axis = 1,inplace = True)

# %%
df
# Out:
#        name  age     city
# 0     jatin   21  germany
# 1  bharteee   18    spain
# 2   supriya   20    india
# 3    mayank   21      USA

# %%
df.drop(3, axis = 0)
# Out:
#        name  age     city
# 0     jatin   21  germany
# 1  bharteee   18    spain
# 2   supriya   20    india

# %%
df.loc[0]
# Out:
# name      jatin
# age          21
# city    germany
# Name: 0, dtype: object

# %%
df.loc[[0,1]]
# Out:
#        name  age     city
# 0     jatin   21  germany
# 1  bharteee   18    spain

# %%
df.loc[[0,1]][['name','city']]
# Out:
#        name     city
# 0     jatin  germany
# 1  bharteee    spain

# %%
df[df['age']>20]
# Out:
#      name  age     city
# 0   jatin   21  germany
# 3  mayank   21      USA

# %%
df[(df['age']>20) & (df['city'] == 'germany')]
# Out:
#     name  age     city
# 0  jatin   21  germany
